# %% [markdown]
# # Participant Data Alignment Script
#
# This script automatically finds all participant folders in your dataset and performs time alignment between EEG (.xdf) files and corresponding Pupil Labs recordings.
#
# !! make sure to install: ***pip install lsl_relay_time_alignment*** before !!
#
# ***Your folder structure should look like this:***
#
# root_dir/
# ├── RP_P001/
# │   ├── RP_P001.xdf
# │   ├── RP_P001_pupil/
# │   │   └── some_time_tag_and_letters/
# │   │       ├── gaze.csv
# │   │       └── time_alignment_parameters.json
# ├── RP_P002/
# │   ├── RP_P002.xdf
# │   ├── RP_P002_pupil/
# │   │   └── …
#
# ***Each participant folder (e.g., RP_P001) must contain:***
# 	•	One .xdf file for EEG
# 	•	One subfolder with _pupil in its name for Pupil Labs data
#
# ***What the script does:***
# 	1.	Loops through each participant directory in the root folder.
# 	2.	Searches for:
# 	•	an .xdf file
# 	•	a subdirectory containing _pupil
# 	3.	Calls the command-line alignment tool lsl_relay_time_alignment using both paths.
#
# ***How to use it:***
# 	1.	Make sure lsl_relay_time_alignment is available in your system’s PATH or provide its full path in the script.
# 	2.	Adjust root_dir to your actual dataset location.
# 	3.	Run the script from a code cell.

# %%
import os
import subprocess
import json
import pandas as pd


# data directory where all participants are stored
data_dir = "/Users/julianreiser/Downloads/mbt_workshop/data/shaggyData"

# Script to run
alignment_script = "lsl_relay_time_alignment"

# %% [markdown]
# ### 1.1 Parameter calculation
# This notebook automates the synchronization of EEG data (from `.xdf` files) with gaze data (from Pupil Labs recordings). The data is organized per participant, where each participant folder contains:
#
# ## 🧩 Workflow
# 1. **Traverse Participant Folders**
#    The script iterates through all participant folders within a specified root directory.
# 2. **Find and Select Input Files**
#    - Locates the `.xdf` file within each participant folder.
#    - Identifies the Pupil Labs data folder (e.g., `*_pupil`).
# 3. **Run Alignment Script**
#    Calls the external script `lsl_relay_time_alignment`, which aligns the two data streams and saves a `time_alignment_parameters.json` file.

# %%
# Loop through each participant folder
root_dir = data_dir
print(root_dir)
for participant_folder in os.listdir(root_dir):
    participant_path = os.path.join(root_dir, participant_folder)
    print(participant_path)
    if not os.path.isdir(participant_path):
        continue

    # Find the .xdf file
    xdf_file = next((f for f in os.listdir(participant_path) if f.endswith(".xdf")), None)
    if not xdf_file:
        print(f"No XDF file found in {participant_path}")
        continue
    xdf_path = os.path.join(participant_path, xdf_file)

    # Find the pupil folder (assumed to contain '_pupil' in name)
    pupil_dirs = [d for d in os.listdir(participant_path) if "_pupil" in d and os.path.isdir(os.path.join(participant_path, d))]
    
    print(pupil_dirs)
    if not pupil_dirs:
        print(f"No pupil folder found in {participant_path}")
        continue
    pupil_path = os.path.join(participant_path, pupil_dirs[0])  # Assuming one match
    print(pupil_path)

    # Run the alignment command
    cmd = [alignment_script, xdf_path, pupil_path]
    print(f"Running: {' '.join(cmd)}")
    subprocess.run(cmd)
# Out:
# /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData
# /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/.DS_Store
# /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P003
# ['RP_P003_pupil']
# /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P003/RP_P003_pupil
# Running: lsl_relay_time_alignment /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P003/RP_P003.xdf /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P003/RP_P003_pupil
# [04/08/25 17:30:10] INFO     Saving logs to ./time_sync_posthoc.log   ]8;id=529875;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/cli.py\cli.py]8;;\:]8;id=580421;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/cli.py#189\189]8;;\
#                     INFO     Loading XDF events from   ]8;id=803289;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=795280;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#54\54]8;;\
#                              /Users/julianreiser/Downl
#                              oads/mbt_workshop/data/sh
#                              aggyData/RP_P003/RP_P003.
#                              xdf
#                     INFO     Importing XDF file                     ]8;id=911806;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py\pyxdf.py]8;;\:]8;id=74485;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py#202\202]8;;\
#                              /Users/julianreiser/Downloads/mbt_work
#                              shop/data/shaggyData/RP_P003/RP_P003.x
#                              df...
#                     INFO       performing clock synchronization...  ]8;id=837028;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py\pyxdf.py]8;;\:]8;id=787349;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py#361\361]8;;\
#                     INFO       performing jitter removal...         ]8;id=776888;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py\pyxdf.py]8;;\:]8;id=950583;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py#374\374]8;;\
#                     WARNING  Session id missing!      ]8;id=660557;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=260152;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#107\107]8;;\
#                              Skipping incompatible
#                              Pupil Companion stream
#                              [{'acquisition':
#                              [{'manufacturer':
#                              ['Pupil Labs'], 'model':
#                              ['Neon'], 'session_id':
#                              []}], 'channels':
#                              [{'channel': [{'label':
#                              ['Event'], 'format':
#                              ['string']}]}]}]
#                     ERROR    Could not extract any     ]8;id=227638;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=2373;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#58\58]8;;\
#                              time alignments for
#                              /Users/julianreiser/Downl
#                              oads/mbt_workshop/data/sh
#                              aggyData/RP_P003/RP_P003.
#                              xdf. No valid Pupil
#                              Companion event streams
#                              found!
# /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P002
# ['RP_P002_pupil']
# /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P002/RP_P002_pupil
# Running: lsl_relay_time_alignment /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P002/RP_P002.xdf /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P002/RP_P002_pupil
# [04/08/25 17:30:12] INFO     Saving logs to ./time_sync_posthoc.log   ]8;id=357406;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/cli.py\cli.py]8;;\:]8;id=973837;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/cli.py#189\189]8;;\
#                     INFO     Loading XDF events from   ]8;id=481081;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=391775;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#54\54]8;;\
#                              /Users/julianreiser/Downl
#                              oads/mbt_workshop/data/sh
#                              aggyData/RP_P002/RP_P002.
#                              xdf
#                     INFO     Importing XDF file                     ]8;id=358238;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py\pyxdf.py]8;;\:]8;id=690375;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py#202\202]8;;\
#                              /Users/julianreiser/Downloads/mbt_work
#                              shop/data/shaggyData/RP_P002/RP_P002.x
#                              df...
#                     INFO       performing clock synchronization...  ]8;id=994507;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py\pyxdf.py]8;;\:]8;id=707876;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py#361\361]8;;\
#                     INFO       performing jitter removal...         ]8;id=855244;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py\pyxdf.py]8;;\:]8;id=164493;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py#374\374]8;;\
#                     WARNING  Session id missing!      ]8;id=158251;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=297683;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#107\107]8;;\
#                              Skipping incompatible
#                              Pupil Companion stream
#                              [{'acquisition':
#                              [{'manufacturer':
#                              ['Pupil Labs'], 'model':
#                              ['Neon'], 'session_id':
#                              []}], 'channels':
#                              [{'channel': [{'label':
#                              ['Event'], 'format':
#                              ['string']}]}]}]
#                     INFO     Loading session ids from  ]8;id=224801;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=963278;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#65\65]8;;\
#                              /Users/julianreiser/Downl
#                              oads/mbt_workshop/data/sh
#                              aggyData/RP_P002/RP_P002_
#                              pupil
#                     INFO     Common session ids:       ]8;id=415326;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=349993;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#70\70]8;;\
#                              {'b61c7c34-65fa-4709-a117
#                              -1acadf5e21d6'}
#                     INFO     Processing session        ]8;id=49076;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=869995;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#72\72]8;;\
#                              b61c7c34-65fa-4709-a117-1
#                              acadf5e21d6
#                     INFO     Writing time alignment    ]8;id=299821;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=415790;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#89\89]8;;\
#                              parameters to
#                              /Users/julianreiser/Downl
#                              oads/mbt_workshop/data/sh
#                              aggyData/RP_P002/RP_P002_
#                              pupil/2025-04-07_16-38-42
#                              -9bf3d082/time_alignment_
#                              parameters.json
# /Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/linear_time_model.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cloud_event_data[timestamp_label] = cloud_event_data["timestamp [ns]"] * 1e-9
# /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P001
# ['RP_P001_pupil']
# /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P001/RP_P001_pupil
# Running: lsl_relay_time_alignment /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P001/RP_P001.xdf /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P001/RP_P001_pupil
# [04/08/25 17:30:13] INFO     Saving logs to ./time_sync_posthoc.log   ]8;id=916798;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/cli.py\cli.py]8;;\:]8;id=884914;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/cli.py#189\189]8;;\
#                     INFO     Loading XDF events from   ]8;id=772142;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=387259;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#54\54]8;;\
#                              /Users/julianreiser/Downl
#                              oads/mbt_workshop/data/sh
#                              aggyData/RP_P001/RP_P001.
#                              xdf
#                     INFO     Importing XDF file                     ]8;id=321008;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py\pyxdf.py]8;;\:]8;id=837401;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py#202\202]8;;\
#                              /Users/julianreiser/Downloads/mbt_work
#                              shop/data/shaggyData/RP_P001/RP_P001.x
#                              df...
# [04/08/25 17:30:14] INFO       performing clock synchronization...  ]8;id=340411;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py\pyxdf.py]8;;\:]8;id=85115;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py#361\361]8;;\
#                     INFO       performing jitter removal...         ]8;id=289146;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py\pyxdf.py]8;;\:]8;id=157292;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pyxdf/pyxdf.py#374\374]8;;\
#                     WARNING  Session id missing!      ]8;id=457200;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=908883;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#107\107]8;;\
#                              Skipping incompatible
#                              Pupil Companion stream
#                              [{'acquisition':
#                              [{'manufacturer':
#                              ['Pupil Labs'], 'model':
#                              ['Neon'], 'session_id':
#                              []}], 'channels':
#                              [{'channel': [{'label':
#                              ['Event'], 'format':
#                              ['string']}]}]}]
#                     INFO     Loading session ids from  ]8;id=922953;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=510939;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#65\65]8;;\
#                              /Users/julianreiser/Downl
#                              oads/mbt_workshop/data/sh
#                              aggyData/RP_P001/RP_P001_
#                              pupil
#                     INFO     Common session ids:       ]8;id=807032;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=198507;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#70\70]8;;\
#                              {'b61c7c34-65fa-4709-a117
#                              -1acadf5e21d6'}
#                     INFO     Processing session        ]8;id=988279;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=49895;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#72\72]8;;\
#                              b61c7c34-65fa-4709-a117-1
#                              acadf5e21d6
#                     INFO     Writing time alignment    ]8;id=137238;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py\xdf_cloud_time_sync.py]8;;\:]8;id=473246;file:///Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/xdf_cloud_time_sync.py#89\89]8;;\
#                              parameters to
#                              /Users/julianreiser/Downl
#                              oads/mbt_workshop/data/sh
#                              aggyData/RP_P001/RP_P001_
#                              pupil/2025-04-07_16-16-06
#                              -e21bc0a3/time_alignment_
#                              parameters.json
# /Users/julianreiser/miniconda3/lib/python3.12/site-packages/pupil_labs/lsl_relay/linear_time_model.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cloud_event_data[timestamp_label] = cloud_event_data["timestamp [ns]"] * 1e-9

# %% [markdown]
# ### 1.2 Gaze Data Time Alignment for All Participants
# 4. **Post-Alignment Processing**
#    - Loads the gaze data CSV file exported from Pupil Cloud.
#    - Uses the alignment parameters to convert timestamps to the LSL time domain.
#    - Saves the aligned gaze data as a new CSV file.
#
# Steps:
# - Read `gaze.csv` and `time_alignment_parameters.json` from nested pupil folders
# - Convert timestamps from nanoseconds to seconds
# - Apply linear mapping using intercept and slope from alignment JSON
# - Save the new file as `time_aligned_gaze.csv` in the same folder

# %%
import os
import json
import pandas as pd

# List all participant directories (e.g., RP_P001, RP_P002, ...)
participants = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
print("Participants found:", participants)

# Linear mapping function
def perform_linear_mapping(input_data, parameters):
    return parameters["intercept"] + input_data * parameters["slope"]

# Loop over participants
for participant in participants:
    participant_dir = os.path.join(data_dir, participant)
    pupil_base_dir = os.path.join(participant_dir, f"{participant}_pupil")

    if not os.path.exists(pupil_base_dir):
        print(f"⚠ Pupil folder not found for {participant}, skipping.")
        continue

    # Get list of timestamped subfolders (should only be one ideally)
    timestamped_dirs = [d for d in os.listdir(pupil_base_dir) if os.path.isdir(os.path.join(pupil_base_dir, d))]

    if not timestamped_dirs:
        print(f"⚠ No timestamped folders found in {pupil_base_dir}, skipping.")
        continue

    # Use the latest timestamped folder (sorted alphabetically)
    timestamped_dirs.sort()
    pupil_data_dir = os.path.join(pupil_base_dir, timestamped_dirs[-1])

    # File paths
    gaze_file = os.path.join(pupil_data_dir, "gaze.csv")
    params_file = os.path.join(pupil_data_dir, "time_alignment_parameters.json")

    print(f"\nProcessing {participant} in folder {timestamped_dirs[-1]}")

    if os.path.exists(gaze_file) and os.path.exists(params_file):
        # Load gaze data
        cloud_gaze_data = pd.read_csv(gaze_file)
        cloud_gaze_data["timestamp [s]"] = cloud_gaze_data["timestamp [ns]"] * 1e-9

        # Load alignment parameters
        with open(params_file, "r") as file:
            parameter_dict = json.load(file)

        # Apply linear mapping
        cloud_gaze_data["lsl_time [s]"] = perform_linear_mapping(
            cloud_gaze_data["timestamp [s]"], parameter_dict["cloud_to_lsl"]
        )

        # Save aligned data
        aligned_file = os.path.join(pupil_data_dir, "time_aligned_gaze.csv")
        cloud_gaze_data.to_csv(aligned_file, index=False)
        print(f"✔ Time-aligned data saved at {aligned_file}")

    else:
        print(f"⚠ Missing gaze or JSON file for {participant}, skipping.")
# Out:
# Participants found: ['RP_P003', 'RP_P002', 'RP_P001']
#
# Processing RP_P003 in folder 2025-04-08_12-51-08-0a75252e
# ⚠ Missing gaze or JSON file for RP_P003, skipping.
#
# Processing RP_P002 in folder 2025-04-07_16-38-42-9bf3d082
# ✔ Time-aligned data saved at /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P002/RP_P002_pupil/2025-04-07_16-38-42-9bf3d082/time_aligned_gaze.csv
#
# Processing RP_P001 in folder 2025-04-07_16-16-06-e21bc0a3
# ✔ Time-aligned data saved at /Users/julianreiser/Downloads/mbt_workshop/data/shaggyData/RP_P001/RP_P001_pupil/2025-04-07_16-16-06-e21bc0a3/time_aligned_gaze.csv
